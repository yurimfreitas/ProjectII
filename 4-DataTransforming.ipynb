# %% [markdown]
# # 1 Import from pkl files

# %%
import joblib
import matplotlib.pyplot as plt

df_sales = joblib.load('df_sales_silver.pkl')
df_product = joblib.load('df_product_silver.pkl')
df_cities = joblib.load('df_cities_silver.pkl')
df_forecast_revenue = joblib.load('df_forecast_revenue_silver.pkl')

# %% [markdown]
# # 2 Joining data

# %%
import pandas as pd

# Join the dataframes on the 'store_id' column (sales and cities)
df_sales_comp = pd.merge(df_sales, df_cities, on='store_id')

# %%
df_sales_comp
# Out:
#               ID store_id product_id       date  sales  revenue  stock  \
# 0              1    S0002      P0001 2017-01-02    0.0     0.00    8.0
# 1              2    S0002      P0005 2017-01-02    0.0     0.00   11.0
# 2              3    S0002      P0011 2017-01-02    0.0     0.00    9.0
# 3              4    S0002      P0015 2017-01-02    1.0     2.41   19.0
# 4              5    S0002      P0017 2017-01-02    0.0     0.00   12.0
# ...          ...      ...        ...        ...    ...      ...    ...
# 8818108  8885578    S0143      P0676 2019-10-24    0.0     0.00    0.0
# 8818109  8885579    S0143      P0680 2019-10-24    0.0     0.00    0.0
# 8818110  8885580    S0143      P0694 2019-10-24    0.0     0.00    0.0
# 8818111  8885581    S0143      P0718 2019-10-24    0.0     0.00    0.0
# 8818112  8885582    S0143      P0747 2019-10-24    0.0     0.00    0.0
#
#           price promo_type_1     promo_bin_1 promo_type_2     promo_bin_2  \
# 0          6.25         PR14  No promo bin 1         PR03  No promo bin 2
# 1         33.90         PR14  No promo bin 1         PR03  No promo bin 2
# 2         49.90         PR14  No promo bin 1         PR03  No promo bin 2
# 3          2.60         PR14  No promo bin 1         PR03  No promo bin 2
# 4          1.49         PR14  No promo bin 1         PR03  No promo bin 2
# ...         ...          ...             ...          ...             ...
# 8818108   19.90         PR03         verylow         PR03  No promo bin 2
# 8818109  139.90         PR14  No promo bin 1         PR03  No promo bin 2
# 8818110    7.50         PR14  No promo bin 1         PR03  No promo bin 2
# 8818111   23.75         PR14  No promo bin 1         PR03  No promo bin 2
# 8818112   21.90         PR14  No promo bin 1         PR03  No promo bin 2
#
#          promo_discount_2 promo_discount_type_2 storetype_id  store_size  \
# 0                     0.0                     0         ST04          39
# 1                     0.0                     0         ST04          39
# 2                     0.0                     0         ST04          39
# 3                     0.0                     0         ST04          39
# 4                     0.0                     0         ST04          39
# ...                   ...                   ...          ...         ...
# 8818108               0.0                     0         ST03          13
# 8818109               0.0                     0         ST03          13
# 8818110               0.0                     0         ST03          13
# 8818111               0.0                     0         ST03          13
# 8818112               0.0                     0         ST03          13
#
#         city_id_old country_id city_code
# 0              C007     TURKEY     Adana
# 1              C007     TURKEY     Adana
# 2              C007     TURKEY     Adana
# 3              C007     TURKEY     Adana
# 4              C007     TURKEY     Adana
# ...             ...        ...       ...
# 8818108        C014     TURKEY  Istanbul
# 8818109        C014     TURKEY  Istanbul
# 8818110        C014     TURKEY  Istanbul
# 8818111        C014     TURKEY  Istanbul
# 8818112        C014     TURKEY  Istanbul
#
# [8818113 rows x 19 columns]

# %%
# Join the dataframes on the 'product_id' column (sales_comp and products)
df_sales_comp = pd.merge(df_sales_comp, df_product, on='product_id')

# %%
df_sales_comp
# Out:
#               ID store_id product_id       date  sales  revenue  stock  \
# 0              1    S0002      P0001 2017-01-02    0.0     0.00    8.0
# 1              2    S0002      P0005 2017-01-02    0.0     0.00   11.0
# 2              3    S0002      P0011 2017-01-02    0.0     0.00    9.0
# 3              4    S0002      P0015 2017-01-02    1.0     2.41   19.0
# 4              5    S0002      P0017 2017-01-02    0.0     0.00   12.0
# ...          ...      ...        ...        ...    ...      ...    ...
# 8818108  8885578    S0143      P0676 2019-10-24    0.0     0.00    0.0
# 8818109  8885579    S0143      P0680 2019-10-24    0.0     0.00    0.0
# 8818110  8885580    S0143      P0694 2019-10-24    0.0     0.00    0.0
# 8818111  8885581    S0143      P0718 2019-10-24    0.0     0.00    0.0
# 8818112  8885582    S0143      P0747 2019-10-24    0.0     0.00    0.0
#
#           price promo_type_1     promo_bin_1  ... city_code product_length  \
# 0          6.25         PR14  No promo bin 1  ...     Adana           13.5
# 1         33.90         PR14  No promo bin 1  ...     Adana           16.0
# 2         49.90         PR14  No promo bin 1  ...     Adana            9.0
# 3          2.60         PR14  No promo bin 1  ...     Adana           10.0
# 4          1.49         PR14  No promo bin 1  ...     Adana            8.0
# ...         ...          ...             ...  ...       ...            ...
# 8818108   19.90         PR03         verylow  ...  Istanbul            2.0
# 8818109  139.90         PR14  No promo bin 1  ...  Istanbul            9.5
# 8818110    7.50         PR14  No promo bin 1  ...  Istanbul           11.0
# 8818111   23.75         PR14  No promo bin 1  ...  Istanbul            5.0
# 8818112   21.90         PR14  No promo bin 1  ...  Istanbul           23.0
#
#          product_depth product_width cluster_id  hierarchy1_id hierarchy2_id  \
# 0                 22.0          20.0  cluster_5            H01         H0105
# 1                 30.0          16.0  cluster_9            H03         H0312
# 2                 22.0          15.0  cluster_0            H03         H0315
# 3                 33.0          10.0  cluster_1            H00         H0000
# 4                 28.0           8.0  cluster_6            H00         H0000
# ...                ...           ...        ...            ...           ...
# 8818108            2.0          44.5  cluster_0            H03         H0312
# 8818109           20.0          14.0  cluster_4            H01         H0107
# 8818110           16.0          16.0  cluster_9            H00         H0000
# 8818111           18.0          10.0  cluster_0            H00         H0004
# 8818112           23.0          33.3  cluster_0            H01         H0107
#
#         hierarchy3_id hierarchy4_id  hierarchy5_id
# 0             H010501     H01050100    H0105010006
# 1             H031211     H03121109    H0312110917
# 2             H031506     H03150612    H0315061202
# 3             H000003     H00000309    H0000030901
# 4             H000003     H00000310    H0000031001
# ...               ...           ...            ...
# 8818108       H031205     H03120507    H0312050709
# 8818109       H010702     H01070210    H0107021001
# 8818110       H000005     H00000505    H0000050506
# 8818111       H000401     H00040100    H0004010026
# 8818112       H010701     H01070100    H0107010026
#
# [8818113 rows x 28 columns]

# %% [markdown]
# ## 2 Save final CSV file before apply models

# %%
# Save the DataFrame to a CSV file
df_sales_comp.to_csv('./Files/df_sales_comp.csv', index=False)

# %% [markdown]
# ### Add in temporary files to be possible use that in the following notebooks

# %%
import joblib

joblib.dump(df_sales, 'df_sales_golden.pkl')
joblib.dump(df_cities, 'df_cities_golden.pkl')
joblib.dump(df_product, 'df_product_golden.pkl')
joblib.dump(df_forecast_revenue, 'df_forecast_revenue_golden.pkl')
joblib.dump(df_forecast_revenue, 'df_sales_comp.pkl')
# Out:
# ['df_sales_comp.pkl']
